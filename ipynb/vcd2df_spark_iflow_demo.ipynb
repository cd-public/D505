# %% [markdown]
# <a href="https://colab.research.google.com/github/cd-public/D505/blob/master/ipynb/vcd2df_spark_iflow_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cd-public/Isadora.git
# Out:
# Cloning into 'Isadora'...
# remote: Enumerating objects: 5272, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 5272 (delta 5), reused 9 (delta 5), pack-reused 5260 (from 1)
# Receiving objects: 100% (5272/5272), 106.03 MiB | 7.26 MiB/s, done.
# Resolving deltas: 100% (4388/4388), done.
# Updating files: 100% (4176/4176), done.

# %%
ls Isadora/model/r5/vcds
# Out:
# alu_add_sub.vcd                   instr_sltu.vcd
# alu_eq.vcd                        instr_slt.vcd
# alu_lts.vcd                       instr_srai.vcd
# alu_ltu.vcd                       instr_sra.vcd
# alu_out_0_q.vcd                   instr_srli.vcd
# alu_out_0.vcd                     instr_srl.vcd
# alu_out_q.vcd                     instr_sub.vcd
# alu_out.vcd                       instr_sw.vcd
# alu_shl.vcd                       instr_timer.vcd
# alu_shr.vcd                       instr_waitirq.vcd
# alu_wait_2.vcd                    instr_xori.vcd
# alu_wait.vcd                      instr_xor.vcd
# cached_ascii_instr.vcd            irq_active.vcd
# cached_insn_imm.vcd               irq_delay.vcd
# cached_insn_opcode.vcd            irq_mask.vcd
# cached_insn_rd.vcd                irq_pending.vcd
# cached_insn_rs1.vcd               irq_state.vcd
# cached_insn_rs2.vcd               is_alu_reg_imm.vcd
# clear_prefetched_high_word_q.vcd  is_alu_reg_reg.vcd
# clear_prefetched_high_word.vcd    is_beq_bne_blt_bge_bltu_bgeu.vcd
# compressed_instr.vcd              is_compare.vcd
# count_cycle.vcd                   is_jalr_addi_slti_sltiu_xori_ori_andi.vcd
# count_instr.vcd                   is_lb_lh_lw_lbu_lhu.vcd
# cpuregs_rs1.vcd                   is_lbu_lhu_lw.vcd
# cpuregs_rs2.vcd                   is_lui_auipc_jal_jalr_addi_add_sub.vcd
# cpuregs_wrdata.vcd                is_lui_auipc_jal.vcd
# cpuregs_write.vcd                 is_sb_sh_sw.vcd
# cpu_state.vcd                     is_slli_srli_srai.vcd
# current_pc.vcd                    is_sll_srl_sra.vcd
# dbg_ascii_instr.vcd               is_slti_blt_slt.vcd
# dbg_ascii_state.vcd               is_sltiu_bltu_sltu.vcd
# dbg_insn_addr.vcd                 last_mem_valid.vcd
# dbg_insn_imm.vcd                  latched_branch.vcd
# dbg_insn_opcode.vcd               latched_compr.vcd
# dbg_insn_rd.vcd                   latched_is_lb.vcd
# dbg_insn_rs1.vcd                  latched_is_lh.vcd
# dbg_insn_rs2.vcd                  latched_is_lu.vcd
# dbg_next.vcd                      latched_rd.vcd
# dbg_rs1val_valid.vcd              latched_stalu.vcd
# dbg_rs1val.vcd                    latched_store.vcd
# dbg_rs2val_valid.vcd              latched_trace.vcd
# dbg_rs2val.vcd                    mem_16bit_buffer.vcd
# dbg_valid_insn.vcd                mem_addr.vcd
# decoded_imm_j.vcd                 mem_do_prefetch.vcd
# decoded_imm.vcd                   mem_do_rdata.vcd
# decoded_rd.vcd                    mem_do_rinst.vcd
# decoded_rs1.vcd                   mem_do_wdata.vcd
# decoded_rs2.vcd                   mem_instr.vcd
# decoded_rs.vcd                    mem_la_firstword_reg.vcd
# decoder_pseudo_trigger_q.vcd      mem_la_secondword.vcd
# decoder_pseudo_trigger.vcd        mem_la_wdata.vcd
# decoder_trigger_q.vcd             mem_la_wstrb.vcd
# decoder_trigger.vcd               mem_rdata_q.vcd
# do_waitirq.vcd                    mem_rdata_word.vcd
# eoi.vcd                           mem_state.vcd
# instr_addi.vcd                    mem_valid.vcd
# instr_add.vcd                     mem_wdata.vcd
# instr_andi.vcd                    mem_wordsize.vcd
# instr_and.vcd                     mem_wstrb.vcd
# instr_auipc.vcd                   new_ascii_instr.vcd
# instr_beq.vcd                     next_insn_opcode.vcd
# instr_bgeu.vcd                    next_irq_pending.vcd
# instr_bge.vcd                     pcpi_insn.vcd
# instr_bltu.vcd                    pcpi_int_rd.vcd
# instr_blt.vcd                     pcpi_int_ready.vcd
# instr_bne.vcd                     pcpi_int_wait.vcd
# instr_ecall_ebreak.vcd            pcpi_int_wr.vcd
# instr_getq.vcd                    pcpi_timeout_counter.vcd
# instr_jalr.vcd                    pcpi_timeout.vcd
# instr_jal.vcd                     pcpi_valid.vcd
# instr_lbu.vcd                     prefetched_high_word.vcd
# instr_lb.vcd                      q_ascii_instr.vcd
# instr_lhu.vcd                     q_insn_imm.vcd
# instr_lh.vcd                      q_insn_opcode.vcd
# instr_lui.vcd                     q_insn_rd.vcd
# instr_lw.vcd                      q_insn_rs1.vcd
# instr_maskirq.vcd                 q_insn_rs2.vcd
# instr_ori.vcd                     reg_next_pc.vcd
# instr_or.vcd                      reg_op1.vcd
# instr_rdcycleh.vcd                reg_op2.vcd
# instr_rdcycle.vcd                 reg_out.vcd
# instr_rdinstrh.vcd                reg_pc.vcd
# instr_rdinstr.vcd                 reg_sh.vcd
# instr_retirq.vcd                  set_mem_do_rdata.vcd
# instr_sb.vcd                      set_mem_do_rinst.vcd
# instr_setq.vcd                    set_mem_do_wdata.vcd
# instr_sh.vcd                      timer.vcd
# instr_slli.vcd                    trace_data.vcd
# instr_sll.vcd                     trace_valid.vcd
# instr_sltiu.vcd                   trap.vcd
# instr_slti.vcd

# %%
# adapted from https://github.com/vcd2df/py
# use a generator over a split (still lazy) instead of file ptr

# on my device, /home/user/.local/bin/spark-submit script.py

import pandas as pd
import pickle

def get_vars(lines):
    line = next(lines)
    vars = {} # insertion order >= 3.7
    while "$enddefinitions" not in line:
        if "var" in line:
            parts = line.split()
            if parts[4] not in vars.values():
                vars[parts[3]] = parts[4]
        line = next(lines)
    return vars

def str2df(str):
    lines = (line for line in str.splitlines())
    vars = get_vars(lines)
    names = vars.copy()
    vars = {var:-1 for var in vars.keys()}
    df = {}
    while "$dumpvars" not in next(lines):
        pass
    time = "#0"
    for line in lines:
        if "#" in line[0]: # Check for tick
            df[time] = pd.Series(vars.values())
            time = line.strip()
        else: # Else two cases, words and bits
            if " " in line: # word
                val, var = line[1:].strip().split()
            else: # bit
                val, var = line[0], line[1:].strip()
            if var in vars:
                vars[var] = int(val, 2) if val.isdigit() else -1
    df = pd.DataFrame(df, dtype=int)
    df.index = names.values()
    return df

# "shadow" registers contain iflow status
# find changes from 0 to 1 at nonzero times
def iflow_times(local):
    local = local[local.index.str.contains("shadow")]
    local = local[local.any(axis=1)]
    local = local.idxmax(axis=1)
    local = local[local != "#0"]
    local = local.apply(lambda s : int(s[1:]))
    return local

from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Python Spark SQL vcd2df iflow demo").getOrCreate()

from pyspark.sql.functions import col, udf, input_file_name

# VCDs from here: https://github.com/cd-public/Isadora/tree/master/model/single/vcds
# Set path appropriately, perhaps
df = spark.read.text("Isadora/model/r5/vcds/*.vcd", wholetext=True).withColumn("filename", input_file_name())
df = df.select(col("value"), udf(lambda fn : fn.split("/")[-1].split(".")[0])(col("filename")).alias("src"))
# switch from udf to rdd map to not wrangle schema
mid = df.rdd.map(lambda x: {x[1].replace("shadow_",""):iflow_times(str2df(x[0]))})
xs = [x for x in mid.collect() if not list(x.values())[0].empty] # reduce stage
spark.stop()

# %%
xs
# Out:
# [{'decoder_trigger_q': shadow_q_insn_rd        10000
#   shadow_q_insn_imm       10000
#   shadow_q_ascii_instr    10000
#   shadow_q_insn_rs2       10000
#   shadow_q_insn_opcode    10000
#   shadow_q_insn_rs1       10000
#   dtype: int64},
#  {'instr_sub': shadow_mem_wdata         1310000
#   shadow_mem_addr          1130000
#   shadow_alu_shr           1100000
#   shadow_alu_shl           1100000
#   shadow_alu_out_q           10000
#   shadow_cpuregs_rs2       1190000
#   shadow_cpuregs_rs1       1080000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1100000
#   shadow_cpuregs_wrdata    1070000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_op1           1100000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1100000
#   shadow_alu_ltu           1100000
#   shadow_alu_lts           1100000
#   dtype: int64},
#  {'instr_lbu': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_mem_rdata_word    1190000
#   shadow_mem_wordsize      1190000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wstrb      1190000
#   shadow_mem_la_wdata      1190000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'instr_lhu': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_mem_rdata_word    1190000
#   shadow_mem_wordsize      1190000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wstrb      1190000
#   shadow_mem_la_wdata      1190000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'instr_lb': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_mem_rdata_word    1190000
#   shadow_mem_wordsize      1190000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wstrb      1190000
#   shadow_mem_la_wdata      1190000
#   shadow_latched_is_lb     1190000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'instr_lh': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_mem_rdata_word    1190000
#   shadow_mem_wordsize      1190000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wstrb      1190000
#   shadow_mem_la_wdata      1190000
#   shadow_latched_is_lh     1190000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'is_lbu_lhu_lw': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_latched_is_lu     1190000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'latched_is_lb': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'latched_is_lh': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'latched_is_lu': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'mem_rdata_word': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'mem_wordsize': shadow_mem_wdata         1130000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_mem_wstrb         1130000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_out           1220000
#   shadow_reg_op1           1240000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'reg_out': shadow_mem_wdata         1310000
#   shadow_alu_shl           1240000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1230000
#   shadow_dbg_rs2val        1280000
#   shadow_dbg_rs1val        1240000
#   shadow_cpuregs_wrdata    1220000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_reg_op1           1240000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'latched_stalu': shadow_mem_wdata         1310000
#   shadow_alu_shl           1280000
#   shadow_alu_add_sub       1240000
#   shadow_alu_out_q         1250000
#   shadow_alu_out           1240000
#   shadow_cpuregs_rs2       1260000
#   shadow_cpuregs_rs1       1410000
#   shadow_dbg_rs2val        1280000
#   shadow_cpuregs_wrdata    1250000
#   shadow_reg_op2           1280000
#   shadow_reg_sh            1280000
#   shadow_mem_la_wdata      1280000
#   shadow_alu_eq            1240000
#   shadow_alu_ltu           1240000
#   shadow_alu_lts           1240000
#   dtype: int64},
#  {'is_alu_reg_reg': shadow_alu_out_q          1110000
#   shadow_alu_out            1100000
#   shadow_instr_add          1200000
#   shadow_instr_slt          1090000
#   shadow_is_slti_blt_slt    1100000
#   shadow_is_compare         1100000
#   shadow_alu_out_0          1100000
#   shadow_alu_out_0_q        1110000
#   dtype: int64},
#  {'instr_add': shadow_alu_out_q    10000
#   dtype: int64},
#  {'cpuregs_rs2': shadow_mem_wdata       1130000
#   shadow_alu_shl         1100000
#   shadow_alu_add_sub     1100000
#   shadow_alu_out_q       1330000
#   shadow_alu_out         1320000
#   shadow_dbg_rs2val      1100000
#   shadow_reg_op2         1100000
#   shadow_reg_sh          1100000
#   shadow_mem_la_wdata    1100000
#   shadow_alu_eq          1100000
#   shadow_alu_ltu         1100000
#   shadow_alu_lts         1100000
#   dtype: int64},
#  {'decoded_rs2': shadow_mem_wdata       1130000
#   shadow_alu_shl         1100000
#   shadow_alu_add_sub     1100000
#   shadow_alu_out_q       1330000
#   shadow_alu_out         1320000
#   shadow_dbg_rs2val      1100000
#   shadow_reg_op2         1100000
#   shadow_reg_sh          1100000
#   shadow_mem_la_wdata    1100000
#   shadow_alu_eq          1100000
#   shadow_alu_ltu         1100000
#   shadow_alu_lts         1100000
#   dtype: int64},
#  {'instr_sh': shadow_mem_wdata         1130000
#   shadow_mem_wstrb         1130000
#   shadow_mem_rdata_word    1120000
#   shadow_mem_wordsize      1120000
#   shadow_mem_la_wstrb      1120000
#   shadow_mem_la_wdata      1120000
#   dtype: int64},
#  {'instr_sb': shadow_mem_wdata         1130000
#   shadow_mem_wstrb         1130000
#   shadow_mem_rdata_word    1120000
#   shadow_mem_wordsize      1120000
#   shadow_mem_la_wstrb      1120000
#   shadow_mem_la_wdata      1120000
#   dtype: int64},
#  {'instr_bltu': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'instr_bgeu': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'instr_bne': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'instr_blt': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'instr_beq': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'instr_bge': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'is_sb_sh_sw': shadow_reg_pc           1110000
#   shadow_mem_wdata        1120000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1110000
#   Length: 135, dtype: int64},
#  {'instr_sltu': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q        10000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 136, dtype: int64},
#  {'instr_slti': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q        10000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 136, dtype: int64},
#  {'instr_slt': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q        10000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 136, dtype: int64},
#  {'instr_sltiu': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q        10000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 136, dtype: int64},
#  {'latched_compr': shadow_cpuregs_wrdata    1340000
#   dtype: int64},
#  {'instr_jalr': shadow_reg_pc           1080000
#   shadow_mem_wdata        1110000
#   shadow_mem_addr         1080000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1100000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1070000
#   Length: 135, dtype: int64},
#  {'is_alu_reg_imm': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shl          1060000
#   shadow_alu_add_sub      1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 132, dtype: int64},
#  {'reg_op1': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_out_q          10000
#   shadow_alu_out             1000
#                            ...
#   shadow_latched_is_lh    1140000
#   shadow_latched_is_lb    1140000
#   shadow_alu_out_0           1000
#   shadow_alu_out_0_q        10000
#   shadow_cpuregs_write    1140000
#   Length: 132, dtype: int64},
#  {'instr_auipc': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 135, dtype: int64},
#  {'is_lb_lh_lw_lbu_lhu': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 133, dtype: int64},
#  {'decoded_imm': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1140000
#   Length: 135, dtype: int64},
#  {'instr_jal': shadow_reg_pc           1060000
#   shadow_mem_wdata        1070000
#   shadow_mem_addr         1060000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1100000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1050000
#   Length: 135, dtype: int64},
#  {'reg_op2': shadow_reg_pc           1140000
#   shadow_mem_wdata        1130000
#   shadow_mem_addr         1130000
#   shadow_alu_out_q          10000
#   shadow_alu_out             1000
#                            ...
#   shadow_latched_is_lh    1140000
#   shadow_latched_is_lb    1140000
#   shadow_alu_out_0           1000
#   shadow_alu_out_0_q        10000
#   shadow_cpuregs_write    1140000
#   Length: 132, dtype: int64},
#  {'is_beq_bne_blt_bge_bltu_bgeu': shadow_reg_pc           1080000
#   shadow_mem_wdata        1090000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1080000
#   shadow_alu_shl          1080000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 138, dtype: int64},
#  {'alu_add_sub': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 138, dtype: int64},
#  {'instr_lui': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 135, dtype: int64},
#  {'instr_andi': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_ori': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_and': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_or': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_xor': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_lw': shadow_reg_pc           1180000
#   shadow_mem_wdata        1200000
#   shadow_mem_addr         1200000
#   shadow_alu_shr          1170000
#   shadow_alu_shl          1170000
#                            ...
#   shadow_alu_out_0_q      1240000
#   shadow_alu_eq           1170000
#   shadow_alu_ltu          1170000
#   shadow_alu_lts          1170000
#   shadow_cpuregs_write    1180000
#   Length: 133, dtype: int64},
#  {'cpuregs_rs1': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1140000
#   Length: 138, dtype: int64},
#  {'instr_xori': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'instr_sw': shadow_reg_pc           1110000
#   shadow_mem_wdata        1120000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1110000
#   Length: 138, dtype: int64},
#  {'instr_retirq': shadow_reg_pc           1100000
#   shadow_mem_wdata        1110000
#   shadow_mem_addr         1100000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1100000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1090000
#   Length: 139, dtype: int64},
#  {'decoded_rs1': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1140000
#   Length: 134, dtype: int64},
#  {'instr_addi': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 136, dtype: int64},
#  {'decoded_imm_j': shadow_reg_pc           1350000
#   shadow_mem_wdata        1380000
#   shadow_mem_addr         1350000
#   shadow_alu_shr          1370000
#   shadow_alu_shl          1370000
#                            ...
#   shadow_alu_out_0_q      1430000
#   shadow_alu_eq           1370000
#   shadow_alu_ltu          1370000
#   shadow_alu_lts          1370000
#   shadow_cpuregs_write    1370000
#   Length: 134, dtype: int64},
#  {'decoder_pseudo_trigger': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shl          1060000
#   shadow_alu_add_sub      1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 109, dtype: int64},
#  {'mem_rdata_q': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1070000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 137, dtype: int64},
#  {'instr_rdcycleh': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 138, dtype: int64},
#  {'do_waitirq': shadow_reg_pc           1060000
#   shadow_mem_wdata        1070000
#   shadow_mem_addr         1020000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1050000
#   Length: 150, dtype: int64},
#  {'trap': shadow_reg_pc           1060000
#   shadow_mem_wdata        1010000
#   shadow_mem_addr         1010000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1050000
#   Length: 149, dtype: int64},
#  {'instr_rdinstrh': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 138, dtype: int64},
#  {'instr_rdcycle': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 138, dtype: int64},
#  {'instr_rdinstr': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1060000
#   Length: 138, dtype: int64},
#  {'mem_valid': shadow_reg_pc           1060000
#   shadow_mem_wdata        1070000
#   shadow_mem_addr         1060000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1050000
#   Length: 146, dtype: int64},
#  {'mem_do_prefetch': shadow_reg_pc           1050000
#   shadow_mem_wdata        1060000
#   shadow_mem_addr         1010000
#   shadow_alu_shr          1050000
#   shadow_alu_shl          1050000
#                            ...
#   shadow_alu_out_0_q      1050000
#   shadow_alu_eq           1050000
#   shadow_alu_ltu          1050000
#   shadow_alu_lts          1050000
#   shadow_cpuregs_write    1040000
#   Length: 149, dtype: int64},
#  {'mem_do_rdata': shadow_reg_pc           1020000
#   shadow_mem_wdata        1030000
#   shadow_mem_addr         1010000
#   shadow_alu_shr          1020000
#   shadow_alu_shl          1020000
#                            ...
#   shadow_alu_out_0_q      1050000
#   shadow_alu_eq           1020000
#   shadow_alu_ltu          1020000
#   shadow_alu_lts          1020000
#   shadow_cpuregs_write    1020000
#   Length: 149, dtype: int64},
#  {'mem_do_rinst': shadow_reg_pc           1050000
#   shadow_mem_wdata        1060000
#   shadow_mem_addr         1010000
#   shadow_alu_shr          1050000
#   shadow_alu_shl          1050000
#                            ...
#   shadow_alu_out_0_q      1050000
#   shadow_alu_eq           1050000
#   shadow_alu_ltu          1050000
#   shadow_alu_lts          1050000
#   shadow_cpuregs_write    1040000
#   Length: 149, dtype: int64},
#  {'mem_do_wdata': shadow_reg_pc           1020000
#   shadow_mem_wdata        1010000
#   shadow_mem_addr         1010000
#   shadow_alu_shr          1020000
#   shadow_alu_shl          1020000
#                            ...
#   shadow_alu_out_0_q      1050000
#   shadow_alu_eq           1020000
#   shadow_alu_ltu          1020000
#   shadow_alu_lts          1020000
#   shadow_cpuregs_write    1020000
#   Length: 149, dtype: int64},
#  {'mem_state': shadow_reg_pc           1040000
#   shadow_mem_wdata        1050000
#   shadow_mem_addr         1020000
#   shadow_alu_shr          1040000
#   shadow_alu_shl          1040000
#                            ...
#   shadow_alu_out_0_q      1040000
#   shadow_alu_eq           1040000
#   shadow_alu_ltu          1040000
#   shadow_alu_lts          1040000
#   shadow_cpuregs_write    1030000
#   Length: 149, dtype: int64},
#  {'latched_rd': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 138, dtype: int64},
#  {'decoded_rd': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 135, dtype: int64},
#  {'is_jalr_addi_slti_sltiu_xori_ori_andi': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 138, dtype: int64},
#  {'is_lui_auipc_jal': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 138, dtype: int64},
#  {'is_slli_srli_srai': shadow_reg_pc           1070000
#   shadow_mem_wdata        1080000
#   shadow_mem_addr         1090000
#   shadow_alu_shr          1060000
#   shadow_alu_shl          1060000
#                            ...
#   shadow_alu_out_0_q      1110000
#   shadow_alu_eq           1060000
#   shadow_alu_ltu          1060000
#   shadow_alu_lts          1060000
#   shadow_cpuregs_write    1070000
#   Length: 138, dtype: int64},
#  {'alu_out_q': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 138, dtype: int64},
#  {'is_compare': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'is_lui_auipc_jal_jalr_addi_add_sub': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'reg_pc': shadow_mem_wdata        1040000
#   shadow_mem_addr         1050000
#   shadow_alu_shr          1030000
#   shadow_alu_shl          1030000
#   shadow_alu_add_sub      1030000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1030000
#   shadow_alu_ltu          1030000
#   shadow_alu_lts          1030000
#   shadow_cpuregs_write    1030000
#   Length: 149, dtype: int64},
#  {'compressed_instr': shadow_reg_pc           1080000
#   shadow_mem_wdata        1130000
#   shadow_mem_addr         1060000
#   shadow_alu_shr          1120000
#   shadow_alu_shl          1120000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1120000
#   shadow_alu_ltu          1120000
#   shadow_alu_lts          1120000
#   shadow_cpuregs_write    1120000
#   Length: 140, dtype: int64},
#  {'is_sll_srl_sra': shadow_reg_pc           1110000
#   shadow_mem_wdata        1120000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1110000
#   shadow_alu_shl          1110000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1110000
#   shadow_alu_ltu          1110000
#   shadow_alu_lts          1110000
#   shadow_cpuregs_write    1110000
#   Length: 138, dtype: int64},
#  {'alu_out': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 137, dtype: int64},
#  {'cpuregs_write': shadow_reg_pc         1140000
#   shadow_mem_wdata      1170000
#   shadow_mem_addr       1130000
#   shadow_alu_shr        1100000
#   shadow_alu_shl        1100000
#                          ...
#   shadow_alu_out_0      1160000
#   shadow_alu_out_0_q    1170000
#   shadow_alu_eq         1100000
#   shadow_alu_ltu        1100000
#   shadow_alu_lts        1100000
#   Length: 138, dtype: int64},
#  {'latched_branch': shadow_reg_pc         1010000
#   shadow_mem_wdata      1040000
#   shadow_mem_addr       1020000
#   shadow_alu_shr        1030000
#   shadow_alu_shl        1030000
#                          ...
#   shadow_alu_out_0      1050000
#   shadow_alu_out_0_q    1060000
#   shadow_alu_eq         1030000
#   shadow_alu_ltu        1030000
#   shadow_alu_lts        1030000
#   Length: 146, dtype: int64},
#  {'latched_store': shadow_reg_pc         1010000
#   shadow_mem_wdata      1040000
#   shadow_mem_addr       1020000
#   shadow_alu_shr        1030000
#   shadow_alu_shl        1030000
#                          ...
#   shadow_alu_out_0      1050000
#   shadow_alu_out_0_q    1060000
#   shadow_alu_eq         1030000
#   shadow_alu_ltu        1030000
#   shadow_alu_lts        1030000
#   Length: 146, dtype: int64},
#  {'reg_next_pc': shadow_reg_pc           1010000
#   shadow_mem_wdata        1040000
#   shadow_mem_addr         1020000
#   shadow_alu_shr          1030000
#   shadow_alu_shl          1030000
#                            ...
#   shadow_alu_out_0_q      1060000
#   shadow_alu_eq           1030000
#   shadow_alu_ltu          1030000
#   shadow_alu_lts          1030000
#   shadow_cpuregs_write    1030000
#   Length: 148, dtype: int64},
#  {'cpu_state': shadow_reg_pc           1010000
#   shadow_mem_wdata        1020000
#   shadow_mem_addr         1020000
#   shadow_alu_shr          1010000
#   shadow_alu_shl          1010000
#                            ...
#   shadow_alu_out_0_q      1040000
#   shadow_alu_eq           1010000
#   shadow_alu_ltu          1010000
#   shadow_alu_lts          1010000
#   shadow_cpuregs_write    1010000
#   Length: 148, dtype: int64},
#  {'cpuregs_wrdata': shadow_reg_pc           1140000
#   shadow_mem_wdata        1170000
#   shadow_mem_addr         1130000
#   shadow_alu_shr          1100000
#   shadow_alu_shl          1100000
#                            ...
#   shadow_alu_out_0_q      1170000
#   shadow_alu_eq           1100000
#   shadow_alu_ltu          1100000
#   shadow_alu_lts          1100000
#   shadow_cpuregs_write    1140000
#   Length: 138, dtype: int64},
#  {'decoder_trigger': shadow_reg_pc           1020000
#   shadow_mem_wdata        1030000
#   shadow_mem_addr         1020000
#   shadow_alu_shl          1020000
#   shadow_alu_add_sub      1020000
#                            ...
#   shadow_alu_out_0_q      1030000
#   shadow_alu_eq           1020000
#   shadow_alu_ltu          1020000
#   shadow_alu_lts          1020000
#   shadow_cpuregs_write    1010000
#   Length: 108, dtype: int64},
#  {'mem_la_wstrb': shadow_mem_wstrb    1130000
#   dtype: int64},
#  {'alu_eq': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0       1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'alu_lts': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0       1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'alu_ltu': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0       1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'is_slti_blt_slt': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'is_sltiu_bltu_sltu': shadow_alu_out_q      10000
#   shadow_alu_out         1000
#   shadow_alu_out_0_q    10000
#   dtype: int64},
#  {'alu_out_0': shadow_alu_out_q    10000
#   shadow_alu_out       1000
#   dtype: int64},
#  {'mem_la_wdata': shadow_mem_wdata    1130000
#   dtype: int64},
#  {'irq_active': shadow_irq_delay    1050000
#   dtype: int64}]
